# %%
##1. Write a Python program to read an entire text file.

x = open("sample.txt","r")
if x.mode == 'r':
    content = x.read()
print(content)
# Out:
# The Project Gutenberg EBook of First Oration of Cicero Against Catiline, by
# John Henderson
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.net
#
#
# Title: First Oration of Cicero Against Catiline
#        with Notices, Notes and Complete Vocabulary
#
# Author: John Henderson
#
# Release Date: March 31, 2008 [EBook #24967]
#
# Language: Latin
#
# Character set encoding: UTF-8
#
# *** START OF THIS PROJECT GUTENBERG EBOOK FIRST ORATION OF CICERO - CATILINE ***
#
#
#
#
# Produced by Louise Hope, Marilynda Fraser-Cunliffe, and
# the Online Distributed Proofreading Team.
#
#
#
#
#
#
# [This e-text includes a few words of accented Greek:
#
#   δῆτα, ἀγαθός
#
# If the words do not display properly, or if the apostrophes and
# ...

# %%
#Write a Python program to read first n lines of a file.

x = open('sample.txt')
n = int(input('enter the number of lines to read '))
line = [next(x) for item in range(n)]
print(line)
# Out:
# enter the number of lines to read 8
# ['The Project Gutenberg EBook of First Oration of Cicero Against Catiline, by \n', 'John Henderson\n', '\n', 'This eBook is for the use of anyone anywhere at no cost and with\n', 'almost no restrictions whatsoever.  You may copy it, give it away or\n', 're-use it under the terms of the Project Gutenberg License included\n', 'with this eBook or online at www.gutenberg.net\n', '\n']

# %%
#5. Write a Python program to read a file line by line and store it into a list.


x = open('sample.txt','r')
line = [item for item in x]
print(line)
# Out:
# ['The Project Gutenberg EBook of First Oration of Cicero Against Catiline, by \n', 'John Henderson\n', '\n', 'This eBook is for the use of anyone anywhere at no cost and with\n', 'almost no restrictions whatsoever.  You may copy it, give it away or\n', 're-use it under the terms of the Project Gutenberg License included\n', 'with this eBook or online at www.gutenberg.net\n', '\n', '\n', 'Title: First Oration of Cicero Against Catiline\n', '       with Notices, Notes and Complete Vocabulary\n', '\n', 'Author: John Henderson\n', '\n', 'Release Date: March 31, 2008 [EBook #24967]\n', '\n', 'Language: Latin\n', '\n', 'Character set encoding: UTF-8\n', '\n', '*** START OF THIS PROJECT GUTENBERG EBOOK FIRST ORATION OF CICERO - CATILINE ***\n', '\n', '\n', '\n', '\n', 'Produced by Louise Hope, Marilynda Fraser-Cunliffe, and\n', 'the Online Distributed Proofreading Team.\n', '\n', '\n', '\n', '\n', '\n', '\n', '[This e-text includes a few words of accented Greek:\n', '\n', '  δῆτα, ἀγαθός\n'
# ...

# %%
#Write a Python program to append text to a file and display the text.

x = open('sample.txt','a+')
x.write('this is the new line /n')
content = x.read()
print(content)

# %%
#Write a Python program to read last n lines of a file. 
n = int(input('enter the no of lines  '))
x = open('sample.txt', 'r')
for line in x.readlines()[-n:]:
    print(line)
# Out:
# enter the no of lines  5
#
#
# This Web site includes information about Project Gutenberg-tm,
#
# including how to make donations to the Project Gutenberg Literary
#
# Archive Foundation, how to help produce our new eBooks, and how to
#
# subscribe to our email newsletter to hear about new eBooks.

# %%
n = int(input('enter the no of lines  '))
x = open('sample.txt', 'r')
# Out:
# enter the no of lines  5

# %%
content = x.readlines()
for line in content[-n:]:
    print(line)
# Out:
# This Web site includes information about Project Gutenberg-tm,
#
# including how to make donations to the Project Gutenberg Literary
#
# Archive Foundation, how to help produce our new eBooks, and how to
#
# subscribe to our email newsletter to hear about new eBooks.

# %%
x = open('sample.txt','r')
content2 = [item for item in x]

# %%
len(content) , len(content2) , content == content2
# Out:
# (5581, 5581, True)

# %%
# Write a Python program to read a file line by line store it into a variable.


x = open('sample.txt','r')
for item in x:
    file += item
print(file)
# Out:
# subscribe to our email newsletter to hear about new eBooks.
# The Project Gutenberg EBook of First Oration of Cicero Against Catiline, by
# John Henderson
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.net
#
#
# Title: First Oration of Cicero Against Catiline
#        with Notices, Notes and Complete Vocabulary
#
# Author: John Henderson
#
# Release Date: March 31, 2008 [EBook #24967]
#
# Language: Latin
#
# Character set encoding: UTF-8
#
# *** START OF THIS PROJECT GUTENBERG EBOOK FIRST ORATION OF CICERO - CATILINE ***
#
#
#
#
# Produced by Louise Hope, Marilynda Fraser-Cunliffe, and
# the Online Distributed Proofreading Team.
#
#
#
#
#
#
# [This e-text includes a few words of accented Greek:
#
#   δῆτα, ἀγαθός
#
# ...

# %%
##Write a python program to find the longest words.


#1. Read text into content using readlines (list of lines)
#2. Wite a function which takes a line and do strip --> split --- return list of words


def fn_preprocess(x):
    words = [item.strip().split() for item in x]
    return(words)


x = open('sample.txt')
content = x.readlines()
y = fn_preprocess(content)

words = [item for item in y]
words2 = [word for item in words for word in item]


length = [len(item) for item in words2]

words2[30829]
# Out:
# 'http://www.gutenberg.org/2/4/9/6/24967/'

# %%
length
max(length)
# Out:
# 39

# %%
for index, item in enumerate(length):
    if (item==39):
        print(index, item)
# Out:
# 30829 39

# %%
help(enumerate
)
# Out:
# Help on class enumerate in module builtins:
#
# class enumerate(object)
#  |  enumerate(iterable, start=0)
#  |
#  |  Return an enumerate object.
#  |
#  |    iterable
#  |      an object supporting iteration
#  |
#  |  The enumerate object yields pairs containing a count (from start, which
#  |  defaults to zero) and a value yielded by the iterable argument.
#  |
#  |  enumerate is useful for obtaining an indexed list:
#  |      (0, seq[0]), (1, seq[1]), (2, seq[2]), ...
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
# ...

# %%
#frquency of words
file=open("sample.txt","r+")

wordcount={}

for word in file.read().split():
    if word not in wordcount:
        wordcount[word] = 1
    else:
        wordcount[word] += 1

for k,v in wordcount.items():
    print(k,v)
# Out:
# The 85
# Project 78
# Gutenberg 21
# EBook 2
# of 721
# First 6
# Oration 4
# Cicero 49
# Against 3
# Catiline, 15
# by 154
# John 3
# Henderson 3
# This 19
# eBook 5
# is 151
# for 125
# the 1139
# use 13
# anyone 5
# anywhere 2
# at 70
# no 56
# cost 2
# and 417
# with 166
# almost 2
# restrictions 2
# whatsoever. 2
# You 13
# may 32
# copy 8
# it, 6
# give 9
# it 46
# away 5
# or 179
# re-use 2
# under 16
# terms 20
# License 8
# included 3
# this 97
# online 4
# www.gutenberg.net 2
# Title: 1
# Catiline 62
# Notices, 2
# Notes 6
# Complete 2
# Vocabulary 4
# Author: 1
# Release 1
# Date: 1
# March 1
# 31, 2
# 2008 1
# [EBook 1
# #24967] 1
# Language: 1
# Latin 4
# Character 1
# set 18
# encoding: 1
# UTF-8 1
# *** 6
# START 1
# OF 16
# THIS 5
# PROJECT 4
# GUTENBERG 3
# EBOOK 2
# FIRST 5
# ORATION 5
# CICERO 3
# - 9
# CATILINE 3
# Produced 2
# Louise 2
# Hope, 2
# Marilynda 2
# Fraser-Cunliffe, 2
# Online 2
# Distributed 2
# Proofreading 2
# Team. 2
# [This 1
# e-text 1
# ...

# %%
#Python program to get the file size of a plain file.

def file_size(fname):
        import os
        statinfo = os.stat(fname)
        return statinfo.st_size

print("File size in bytes of a plain file: ",file_size("sample.txt"))
# Out:
# File size in bytes of a plain file:  223571

# %%
# ython program to write a list to a file. 

list = ['Red', 'Green', 'White', 'Black', 'Pink', 'Yellow']

file=open("sample.txt","w")
for item in list:
    file.write("%s\n"%item)
    
file.close()    

x = open("sample.txt","r")
print(x.read())
# Out:
# Red
# Green
# White
# Black
# Pink
# Yellow

# %%
x = open('sample.txt','r')
y = open('test.txt','w')
from shutil import copyfile
copyfile('sample.txt','test.txt')

x.read().strip()
# Out:
# 'Red\nGreen\nWhite\nBlack\nPink\nYellow'

# %%
# Python program to combine each line from first file with the corresponding line in second file.

with open('sample.txt') as fh1, open('test.txt') as fh2:
    for line1, line2 in zip(fh1, fh2):
        print(line1+line2)
# Out:
# Red
# Red
#
# Green
# Green
#
# White
# White
#
# Black
# Black
#
# Pink
# Pink
#
# Yellow
# Yellow

# %%
help(zip
)
# Out:
# Help on class zip in module builtins:
#
# class zip(object)
#  |  zip(iter1 [,iter2 [...]]) --> zip object
#  |
#  |  Return a zip object whose .__next__() method returns a tuple where
#  |  the i-th element comes from the i-th iterable argument.  The .__next__()
#  |  method continues until the shortest iterable in the argument sequence
#  |  is exhausted and then it raises StopIteration.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
#Write a Python program to read a random line from a file.
import random
def random_line(fname):
    lines = open(fname).read().splitlines()
    return random.choice(lines)
print(random_line('test.txt'))
# Out:
# Pink

# %%
f = open('test.txt','r')
f.close()

if f.close()== True:
    print('Closed')
else:
    print ('Not Closed')
# Out:
# Not Closed

# %%
#Write a Python program to remove newline characters from a file.

def remove_newlines(fname):
    flist = open(fname).readlines()
    return [s.rstrip('\n') for s in flist]

print(remove_newlines("sample.txt"))
# Out:
# ['The Project Gutenberg EBook of First Oration of Cicero Against Catiline, by ', 'John Henderson', '', 'This eBook is for the use of anyone anywhere at no cost and with', 'almost no restrictions whatsoever.  You may copy it, give it away or', 're-use it under the terms of the Project Gutenberg License included', 'with this eBook or online at www.gutenberg.net', '', '', 'Title: First Oration of Cicero Against Catiline', '       with Notices, Notes and Complete Vocabulary', '', 'Author: John Henderson', '', 'Release Date: March 31, 2008 [EBook #24967]', '', 'Language: Latin', '', 'Character set encoding: UTF-8', '', '*** START OF THIS PROJECT GUTENBERG EBOOK FIRST ORATION OF CICERO - CATILINE ***', '', '', '', '', 'Produced by Louise Hope, Marilynda Fraser-Cunliffe, and', 'the Online Distributed Proofreading Team.', '', '', '', '', '', '', '[This e-text includes a few words of accented Greek:', '', '  δῆτα, ἀγαθός', '', 'If the words do not display properly, or if the apostrophes and',
# ...
