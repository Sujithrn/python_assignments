# %%
#open text file
x = open('sample.txt','r')

# %%
content = x.readlines()

# %%
content
# Out:
# 'the project gutenberg ebook of first oration of cicero against catiline, by john hendersonthis ebook is for the use of anyone anywhere at no cost and withalmost no restrictions whatsoever.  you may copy it, give it away orre-use it under the terms of the project gutenberg license includedwith this ebook or online at www.gutenberg.nettitle: first oration of cicero against catiline       with notices, notes and complete vocabularyauthor: john hendersonrelease date: march 31, 2008 [ebook #24967]language: latincharacter set encoding: utf-8*** start of this project gutenberg ebook first oration of cicero - catiline ***produced by louise hope, marilynda fraser-cunliffe, andthe online distributed proofreading team.[this e-text includes a few words of accented greek:  δῆτα, ἀγαθόςif the words do not display properly, or if the apostrophes andquotation marks in this paragraph appear as garbage, make sure yourtext reader’s “character set” or “file encoding” is set to unicode(utf-8). you may a
# ...

# %%
words = content.split()
a = {}

for word in words:
    if word in a:
        a[word] += 1
    else:
        a[word] = 1

# %%
words
# Out:
# ['the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'first',
#  'oration',
#  'of',
#  'cicero',
#  'against',
#  'catiline,',
#  'by',
#  'john',
#  'hendersonthis',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'withalmost',
#  'no',
#  'restrictions',
#  'whatsoever.',
#  'you',
#  'may',
#  'copy',
#  'it,',
#  'give',
#  'it',
#  'away',
#  'orre-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'license',
#  'includedwith',
#  'this',
#  'ebook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.nettitle:',
#  'first',
#  'oration',
#  'of',
#  'cicero',
#  'against',
#  'catiline',
#  'with',
#  'notices,',
#  'notes',
#  'and',
#  'complete',
#  'vocabularyauthor:',
#  'john',
#  'hendersonrelease',
#  'date:',
#  'march',
#  '31,',
#  '2008',
#  '[ebook',
#  '#24967]language:',
#  'latincharacter',
#  'set',
#  'encoding:',
# ...

# %%
list_words = []
for item in words:
    list_words.append([item])

# %%
list_words , b
# Out:
# ([['the'],
#   ['project'],
#   ['gutenberg'],
#   ['ebook'],
#   ['of'],
#   ['first'],
#   ['oration'],
#   ['of'],
#   ['cicero'],
#   ['against'],
#   ['catiline,'],
#   ['by'],
#   ['john'],
#   ['hendersonthis'],
#   ['ebook'],
#   ['is'],
#   ['for'],
#   ['the'],
#   ['use'],
#   ['of'],
#   ['anyone'],
#   ['anywhere'],
#   ['at'],
#   ['no'],
#   ['cost'],
#   ['and'],
#   ['withalmost'],
#   ['no'],
#   ['restrictions'],
#   ['whatsoever.'],
#   ['you'],
#   ['may'],
#   ['copy'],
#   ['it,'],
#   ['give'],
#   ['it'],
#   ['away'],
#   ['orre-use'],
#   ['it'],
#   ['under'],
#   ['the'],
#   ['terms'],
#   ['of'],
#   ['the'],
#   ['project'],
#   ['gutenberg'],
#   ['license'],
#   ['includedwith'],
#   ['this'],
#   ['ebook'],
#   ['or'],
#   ['online'],
#   ['at'],
#   ['www.gutenberg.nettitle:'],
#   ['first'],
#   ['oration'],
#   ['of'],
#   ['cicero'],
#   ['against'],
#   ['catiline'],
#   ['with'],
#   ['notices,'],
#   ['notes'],
#   ['and'],
#   ['complete'],
# ...

# %%
# Out:
# {'the': 1059.0,
#  'project': 63,
#  'gutenberg': 18,
#  'ebook': 9,
#  'of': 665,
#  'first': 24,
#  'oration': 14,
#  'cicero': 44,
#  'against': 17,
#  'catiline,': 14,
#  'by': 139,
#  'john': 3,
#  'hendersonthis': 1,
#  'is': 132,
#  'for': 122,
#  'use': 16,
#  'anyone': 4,
#  'anywhere': 2,
#  'at': 76,
#  'no': 57,
#  'cost': 2,
#  'and': 367,
#  'withalmost': 2,
#  'restrictions': 2,
#  'whatsoever.': 2,
#  'you': 115,
#  'may': 32,
#  'copy': 7,
#  'it,': 3,
#  'give': 12,
#  'it': 50,
#  'away': 5,
#  'orre-use': 2,
#  'under': 15,
#  'terms': 20,
#  'license': 8,
#  'includedwith': 2,
#  'this': 102,
#  'or': 163,
#  'online': 6,
#  'www.gutenberg.nettitle:': 1,
#  'catiline': 53,
#  'with': 147,
#  'notices,': 2,
#  'notes': 6,
#  'complete': 2,
#  'vocabularyauthor:': 1,
#  'hendersonrelease': 1,
#  'date:': 1,
#  'march': 1,
#  '31,': 2,
#  '2008': 1,
#  '[ebook': 1,
#  '#24967]language:': 1,
#  'latincharacter': 1,
#  'set': 15,
#  'encoding:': 1,
#  'utf-8***': 1,
# ...
